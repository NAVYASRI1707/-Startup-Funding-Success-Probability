# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "indian_startup_funding_2020_2025_sample.csv"

# Load the latest version
df = kagglehub.dataset_load(
  KaggleDatasetAdapter.PANDAS,
  "vagdevititikshag/indian-startup-funding-dataset-20202025",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# Using Colab cache for faster access to the 'indian-startup-funding-dataset-20202025' dataset.
# First 5 records:     Startup              Industry   SubVertical       City  \
# 0  Housejoy                EdTech           K12     Mumbai
# 1     Groww                 Media     Streaming  Bengaluru
# 2     Groww              Mobility  Ride Sharing  Hyderabad
# 3   FarmBox  Consumer Electronics     Wearables   Gurugram
# 4     Udaan            RealEstate   Rental Tech     Mumbai
#
#                          Investors InvestmentType  InvestmentAmount_USD  \
# 0                 Lightspeed India           Seed                199000
# 1                              IFC           Seed               1668000
# 2  Nexus Venture Partners, Peak XV       Series B              38052000
# 3    Kalaari Capital, Y Combinator           Seed                455000
# 4        Bessemer Venture Partners           Seed                 89000
#
#          Date
# 0  19-04-2023
# 1  28-01-2025
# 2  14-03-2021
# ...

# %%
df.head()
# Out:
#     Startup              Industry   SubVertical       City  \
# 0  Housejoy                EdTech           K12     Mumbai
# 1     Groww                 Media     Streaming  Bengaluru
# 2     Groww              Mobility  Ride Sharing  Hyderabad
# 3   FarmBox  Consumer Electronics     Wearables   Gurugram
# 4     Udaan            RealEstate   Rental Tech     Mumbai
#
#                          Investors InvestmentType  InvestmentAmount_USD  \
# 0                 Lightspeed India           Seed                199000
# 1                              IFC           Seed               1668000
# 2  Nexus Venture Partners, Peak XV       Series B              38052000
# 3    Kalaari Capital, Y Combinator           Seed                455000
# 4        Bessemer Venture Partners           Seed                 89000
#
#          Date
# 0  19-04-2023
# 1  28-01-2025
# 2  14-03-2021
# 3  11-09-2023
# 4  31-01-2024

# %%
print("Rows and Columns:", df.shape)
# Out:
# Rows and Columns: (1100, 8)

# %%
print(df.columns)
# Out:
# Index(['Startup', 'Industry', 'SubVertical', 'City', 'Investors',
#        'InvestmentType', 'InvestmentAmount_USD', 'Date'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Startup',
#  'Industry',
#  'SubVertical',
#  'City',
#  'Investors',
#  'InvestmentType',
#  'InvestmentAmount_USD',
#  'Date']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Startup               1100 non-null   object
#  1   Industry              1100 non-null   object
#  2   SubVertical           1100 non-null   object
#  3   City                  1100 non-null   object
#  4   Investors             1100 non-null   object
#  5   InvestmentType        1100 non-null   object
#  6   InvestmentAmount_USD  1100 non-null   int64
#  7   Date                  1100 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 68.9+ KB

# %%
df.isnull().sum()
# Out:
# Startup                 0
# Industry                0
# SubVertical             0
# City                    0
# Investors               0
# InvestmentType          0
# InvestmentAmount_USD    0
# Date                    0
# dtype: int64

# %%
df.describe()
# Out:
#        InvestmentAmount_USD
# count          1.100000e+03
# mean           2.553295e+07
# std            7.266655e+07
# min            5.000000e+03
# 25%            1.697500e+05
# 50%            1.114500e+06
# 75%            1.017250e+07
# max            5.746760e+08

# %%
print(df.columns)
# Out:
# Index(['Startup', 'Industry', 'SubVertical', 'City', 'Investors',
#        'InvestmentType', 'InvestmentAmount_USD', 'Date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Startup               1100 non-null   object
#  1   Industry              1100 non-null   object
#  2   SubVertical           1100 non-null   object
#  3   City                  1100 non-null   object
#  4   Investors             1100 non-null   object
#  5   InvestmentType        1100 non-null   object
#  6   InvestmentAmount_USD  1100 non-null   int64
#  7   Date                  1100 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 68.9+ KB

# %%
df.isnull().sum()
# Out:
# Startup                 0
# Industry                0
# SubVertical             0
# City                    0
# Investors               0
# InvestmentType          0
# InvestmentAmount_USD    0
# Date                    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
print(df.shape)
# Out:
# (1100, 8)

# %%
df['InvestmentAmount_USD'].describe()
# Out:
# count    1.100000e+03
# mean     2.553295e+07
# std      7.266655e+07
# min      5.000000e+03
# 25%      1.697500e+05
# 50%      1.114500e+06
# 75%      1.017250e+07
# max      5.746760e+08
# Name: InvestmentAmount_USD, dtype: float64

# %%
print("Median Funding:",
      df['InvestmentAmount_USD'].median())
# Out:
# Median Funding: 1114500.0

# %%
print("Std Dev:",
      df['InvestmentAmount_USD'].std())
# Out:
# Std Dev: 72666549.08494364

# %%
print(df['InvestmentAmount_USD'].quantile([0.25,0.5,0.75]))
# Out:
# 0.25      169750.0
# 0.50     1114500.0
# 0.75    10172500.0
# Name: InvestmentAmount_USD, dtype: float64

# %%
df.groupby('Industry')['InvestmentAmount_USD'].sum().sort_values(ascending=False).head(10)
# Out:
# Industry
# FoodTech                3477282000
# Consumer Electronics    2703489000
# Retail                  2673074000
# Mobility                2460096000
# Media                   2292449000
# AgriTech                2142559000
# E-commerce              1772544000
# FinTech                 1631375000
# SaaS                    1629119000
# EdTech                  1627226000
# Name: InvestmentAmount_USD, dtype: int64

# %%
df.groupby('City')['InvestmentAmount_USD'].sum().sort_values(ascending=False).head(10)
# Out:
# City
# Pune         4435496000
# Kolkata      3590477000
# Delhi        3426493000
# Gurugram     3122328000
# Chennai      2675023000
# Bengaluru    2561458000
# Ahmedabad    2462396000
# Mumbai       2424807000
# Hyderabad    1707975000
# Noida        1679790000
# Name: InvestmentAmount_USD, dtype: int64

# %%
import matplotlib.pyplot as plt

df.groupby('Industry')['InvestmentAmount_USD'].sum()\
.sort_values(ascending=False)\
.head(10)\
.plot(kind='bar')

plt.title("Top Industries by Funding")
plt.show()

# %%
df['InvestmentType'].value_counts()
# Out:
# InvestmentType
# Seed              353
# Series A          227
# Series B          110
# Series C           95
# Pre-Series A       88
# Angel              62
# Pre-Seed           51
# Bridge             39
# Growth             25
# Series D           24
# Debt               21
# Private Equity      5
# Name: count, dtype: int64

# %%
df['InvestmentType'].value_counts()
# Out:
# InvestmentType
# Seed              353
# Series A          227
# Series B          110
# Series C           95
# Pre-Series A       88
# Angel              62
# Pre-Seed           51
# Bridge             39
# Growth             25
# Series D           24
# Debt               21
# Private Equity      5
# Name: count, dtype: int64

# %%
seed_prob = len(df[df['InvestmentType']=='Seed']) / len(df)

print("Probability of Seed Funding:", seed_prob)
# Out:
# Probability of Seed Funding: 0.3209090909090909

# %%
industry_prob = df['Industry'].value_counts(normalize=True)*100

print(industry_prob)
# Out:
# Industry
# E-commerce              8.181818
# Retail                  8.090909
# Consumer Electronics    7.909091
# Mobility                7.818182
# Media                   7.727273
# AgriTech                7.454545
# FoodTech                7.272727
# RealEstate              7.181818
# EdTech                  7.090909
# HealthTech              6.909091
# FinTech                 6.636364
# SaaS                    6.545455
# Enterprise              6.000000
# Logistics               5.181818
# Name: proportion, dtype: float64

# %%
city_prob = df['City'].value_counts(normalize=True)*100

print(city_prob.head(10))
# Out:
# City
# Delhi        11.636364
# Kolkata      10.545455
# Pune         10.272727
# Chennai      10.181818
# Ahmedabad    10.090909
# Gurugram      9.909091
# Bengaluru     9.727273
# Mumbai        9.454545
# Noida         9.454545
# Hyderabad     8.727273
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

df['InvestmentType'].value_counts().plot(kind='bar')

plt.title("Investment Type Distribution")
plt.xlabel("Investment Type")
plt.ylabel("Count")
plt.show()

# %%
industry_funding = df.groupby('Industry')['InvestmentAmount_USD'].mean().sort_values(ascending=False)

print(industry_funding.head(10))
# Out:
# Industry
# FoodTech                4.346602e+07
# Consumer Electronics    3.107459e+07
# Retail                  3.003454e+07
# Mobility                2.860577e+07
# Media                   2.696999e+07
# AgriTech                2.612877e+07
# Logistics               2.407104e+07
# SaaS                    2.262665e+07
# FinTech                 2.234760e+07
# Enterprise              2.142473e+07
# Name: InvestmentAmount_USD, dtype: float64

# %%
city_funding = df.groupby('City')['InvestmentAmount_USD'].mean().sort_values(ascending=False)

print(city_funding.head(10))
# Out:
# City
# Pune         3.925218e+07
# Kolkata      3.095239e+07
# Gurugram     2.864521e+07
# Delhi        2.676948e+07
# Bengaluru    2.393886e+07
# Chennai      2.388413e+07
# Mumbai       2.331545e+07
# Ahmedabad    2.218375e+07
# Hyderabad    1.779141e+07
# Noida        1.615183e+07
# Name: InvestmentAmount_USD, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

sns.boxplot(
    x='Industry',
    y='InvestmentAmount_USD',
    data=df
)

plt.xticks(rotation=90)
plt.show()

# %%
df.describe(include='all')
# Out:
#           Startup    Industry SubVertical   City  Investors InvestmentType  \
# count        1100        1100        1100   1100       1100           1100
# unique        180          14          44     10        423             12
# top     DriveEdge  E-commerce     Fashion  Delhi  Info Edge           Seed
# freq           15          90          67    128         29            353
# mean          NaN         NaN         NaN    NaN        NaN            NaN
# std           NaN         NaN         NaN    NaN        NaN            NaN
# min           NaN         NaN         NaN    NaN        NaN            NaN
# 25%           NaN         NaN         NaN    NaN        NaN            NaN
# 50%           NaN         NaN         NaN    NaN        NaN            NaN
# 75%           NaN         NaN         NaN    NaN        NaN            NaN
# max           NaN         NaN         NaN    NaN        NaN            NaN
#
#         InvestmentAmount_USD        Date
# ...
